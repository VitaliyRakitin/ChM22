# %%
import pandas as pd
import numpy as np
import pylab as pl
# %pylab inline
read_df = pd.read_csv("out.csv",sep = "\t")
#print read_df
t = read_df[[0]].values
x = read_df[[1]].values
y = read_df[[2]].values

pl.plot(t, x)
pl.axis([0, 30 , -2 , 2])
pl.xlabel("t")
pl.ylabel("x")
savefig('01t-x.pdf')

pl.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pl.plot(t,y)
pl.axis([0, 30, -2 , 2])
pl.xlabel("t")
pl.ylabel("y")
savefig('01t-y.pdf')

pl.show()

# %%
pl.plot(x,y)
pl.axis([-2, 2, -2 , 2])
pl.xlabel("x")
pl.ylabel("y")
savefig('01x-y.pdf')

pl.show()

# %%
cmd_1 = 'make'
cmd = './p'
import subprocess

PIPE = subprocess.PIPE
p = subprocess.Popen(cmd_1, shell = True)
p.wait()
p1 = subprocess.Popen(cmd, shell = True)
p1.wait()
print "process finished"
# Out:
# process finished
